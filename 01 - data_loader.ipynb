# %%
import pandas as pd
import json
import os

# %%
with open("data/columns_feature_names.json", "r") as file:
    column_features_dict = json.load(file)

# %%
column_features_dict
# Out:
# {'color': 'white wine, yellow, very pale, pale, pale gold, gold, old gold, full gold, bronze, pale amber, amber, full amber, red, fino sherry',
#  'nose': 'aromatic, peaty, sweet, light, fresh, dry, fruity, grassy, salty, sherry, spicy, rich',
#  'body': 'soft, medium, full, round, smooth, light, firm, oily',
#  'palate': 'full, dry, sherry, big, light, smooth, clean, fruity, grassy, smoky, sweet, spicy, oily, salty, aromatic',
#  'finish': 'full, dry, warm, big, light, smooth, clean, fruity, grassy, smoky, sweet, spicy, oily, salty, aromatic, quick, long, very long, lingering'}

# %%
def load_data(file, data_name):
    features_txt = column_features_dict[data_name]
    features_list = features_txt.split(", ")
    features_list_clean = [feature.replace(" ", "-") for feature in features_list]
    columns = [data_name + "_" +  feature for feature in features_list_clean]
    
    df = pd.read_csv(file, skiprows=1, sep="\s+", header=None)
    df.columns = columns
    
    return df

# %%
df_list = []
file_format = ".TXT"
file_folder = "data"

for data_name in  column_features_dict.keys():
    print("Carregando os dados de " + data_name)
    file = data_name.upper() + file_format
    file_path = os.path.join(file_folder, file)
    df = load_data(file_path, data_name)
    row, col = df.shape
    print("Foram carregados:")
    print("\t observações: " + str(row))
    print("\t atributos: " + str(col))
    print()
    df_list.append(df)
# Out:
# Carregando os dados de color
# Foram carregados:
# 	 observações: 109
# 	 atributos: 14
#
# Carregando os dados de nose
# Foram carregados:
# 	 observações: 109
# 	 atributos: 12
#
# Carregando os dados de body
# Foram carregados:
# 	 observações: 109
# 	 atributos: 8
#
# Carregando os dados de palate
# Foram carregados:
# 	 observações: 109
# 	 atributos: 15
#
# Carregando os dados de finish
# Foram carregados:
# 	 observações: 109
# 	 atributos: 19

# %%
coord_df = (pd.read_csv("data/DISTCOOR.TXT", skiprows=7, header=None)[0].
            str.strip().str.split("\s{3,}", expand=True))
coord_df.columns = ["name", "coord_x", "coord_y"]
coord_df["coord_x"] = coord_df["coord_x"].astype("float")
coord_df["coord_y"] = coord_df["coord_x"].astype("float")

print(coord_df.info())
coord_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     109 non-null    object
#  1   coord_x  109 non-null    float64
#  2   coord_y  109 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 2.7+ KB
# None
#            name  coord_x  coord_y
# 0     Aberfeldy    3.875    3.875
# 1      Aberlour    3.220    3.220
# 2       Ardberg    6.080    6.080
# 3       Ardmore    2.670    2.670
# 4  Auchentoshan    4.390    4.390

# %%
df_list.append(coord_df)

# %%
region_labels = {1: "Highlands", 2: "Islay", 3: "Lowlands"}

regions_df = pd.read_csv("data/REGIONS.TXT", header=None, skipfooter=6, engine="python")
regions_df.columns = ["region"]
regions_df["region"] = regions_df["region"].map(region_labels).astype("category")

print(regions_df.info())
regions_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   region  109 non-null    category
# dtypes: category(1)
# memory usage: 369.0 bytes
# None
#       region
# 0  Highlands
# 1  Highlands
# 2      Islay
# 3  Highlands
# 4   Lowlands

# %%
df_list.append(regions_df)

# %%
df = pd.concat(df_list, axis=1)
df.set_index("name", inplace=True)
df.head()
# Out:
#               color_white-wine  color_yellow  color_very-pale  color_pale  \
# name
# Aberfeldy                    0             1                0           0
# Aberlour                     0             0                0           0
# Ardberg                      0             0                0           0
# Ardmore                      0             0                0           0
# Auchentoshan                 0             0                0           0
#
#               color_pale-gold  color_gold  color_old-gold  color_full-gold  \
# name
# Aberfeldy                   0           0               0                0
# Aberlour                    0           0               0                0
# Ardberg                     0           0               0                0
# Ardmore                     1           0               0                0
# Auchentoshan                1           0               0                0
#
#               color_bronze  color_pale-amber  ...  finish_oily  finish_salty  \
# name                                          ...
# Aberfeldy                0                 0  ...            0             0
# Aberlour                 0                 0  ...            0             0
# Ardberg                  0                 0  ...            0             1
# Ardmore                  0                 0  ...            0             0
# Auchentoshan             0                 0  ...            0             0
#
#               finish_aromatic  finish_quick  finish_long  finish_very-long  \
# name
# Aberfeldy                   0             0            0                 0
# Aberlour                    0             1            0                 0
# Ardberg                     0             0            0                 0
# Ardmore                     0             0            0                 0
# Auchentoshan                0             0            0                 0
#
#               finish_lingering  coord_x  coord_y     region
# name
# Aberfeldy                    0    3.875    3.875  Highlands
# Aberlour                     0    3.220    3.220  Highlands
# Ardberg                      0    6.080    6.080      Islay
# Ardmore                      0    2.670    2.670  Highlands
# Auchentoshan                 0    4.390    4.390   Lowlands
#
# [5 rows x 71 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, Aberfeldy to Tullibardine
# Data columns (total 71 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   color_white-wine   109 non-null    int64
#  1   color_yellow       109 non-null    int64
#  2   color_very-pale    109 non-null    int64
#  3   color_pale         109 non-null    int64
#  4   color_pale-gold    109 non-null    int64
#  5   color_gold         109 non-null    int64
#  6   color_old-gold     109 non-null    int64
#  7   color_full-gold    109 non-null    int64
#  8   color_bronze       109 non-null    int64
#  9   color_pale-amber   109 non-null    int64
#  10  color_amber        109 non-null    int64
#  11  color_full-amber   109 non-null    int64
#  12  color_red          109 non-null    int64
#  13  color_fino-sherry  109 non-null    int64
#  14  nose_aromatic      109 non-null    int64
#  15  nose_peaty         109 non-null    int64
#  16  nose_sweet         109 non-null    int64
#  17  nose_light         109 non-null    int64
#  18  nose_fresh         109 non-null    int64
#  19  nose_dry           109 non-null    int64
#  20  nose_fruity        109 non-null    int64
#  21  nose_grassy        109 non-null    int64
#  22  nose_salty         109 non-null    int64
#  23  nose_sherry        109 non-null    int64
#  24  nose_spicy         109 non-null    int64
#  25  nose_rich          109 non-null    int64
#  26  body_soft          109 non-null    int64
#  27  body_medium        109 non-null    int64
#  28  body_full          109 non-null    int64
#  29  body_round         109 non-null    int64
#  30  body_smooth        109 non-null    int64
#  31  body_light         109 non-null    int64
#  32  body_firm          109 non-null    int64
#  33  body_oily          109 non-null    int64
#  34  palate_full        109 non-null    int64
#  35  palate_dry         109 non-null    int64
#  36  palate_sherry      109 non-null    int64
#  37  palate_big         109 non-null    int64
#  38  palate_light       109 non-null    int64
#  39  palate_smooth      109 non-null    int64
#  40  palate_clean       109 non-null    int64
#  41  palate_fruity      109 non-null    int64
#  42  palate_grassy      109 non-null    int64
#  43  palate_smoky       109 non-null    int64
#  44  palate_sweet       109 non-null    int64
#  45  palate_spicy       109 non-null    int64
#  46  palate_oily        109 non-null    int64
#  47  palate_salty       109 non-null    int64
#  48  palate_aromatic    109 non-null    int64
#  49  finish_full        109 non-null    int64
#  50  finish_dry         109 non-null    int64
#  51  finish_warm        109 non-null    int64
#  52  finish_big         109 non-null    int64
#  53  finish_light       109 non-null    int64
#  54  finish_smooth      109 non-null    int64
#  55  finish_clean       109 non-null    int64
#  56  finish_fruity      109 non-null    int64
#  57  finish_grassy      109 non-null    int64
#  58  finish_smoky       109 non-null    int64
#  59  finish_sweet       109 non-null    int64
#  60  finish_spicy       109 non-null    int64
#  61  finish_oily        109 non-null    int64
#  62  finish_salty       109 non-null    int64
#  63  finish_aromatic    109 non-null    int64
#  64  finish_quick       109 non-null    int64
#  65  finish_long        109 non-null    int64
#  66  finish_very-long   109 non-null    int64
#  67  finish_lingering   109 non-null    int64
#  68  coord_x            109 non-null    float64
#  69  coord_y            109 non-null    float64
#  70  region             109 non-null    category
# dtypes: category(1), float64(2), int64(68)
# memory usage: 60.7+ KB

# %%
df.to_pickle("data/data.pickle")
